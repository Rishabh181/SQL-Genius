# %%
import pandas as pd 
import numpy as np
import os

# %%
os.environ['GOOGLE_API_KEY'] = "AIzaSyDOmG9VLDhhCnOt8bUnMw5oURysaTsCzVM"
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain.chains import SequentialChain
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
api_key = "AIzaSyDOmG9VLDhhCnOt8bUnMw5oURysaTsCzVM"

# %%
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash",temperature= 0.5)

# %%
from langchain.llms import GooglePalm
llm = GooglePalm(model = "gemini-1.5-flash", google_api_key = api_key, temperature =  0.2)

# %%
poem = llm.generate_content("write a poem on mobile phone")
print(poem.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 poem = llm.generate_content("write a poem on mobile phone")
#       2 print(poem.text)
#
# File c:\Users\User\anaconda3\Lib\site-packages\pydantic\main.py:989, in BaseModel.__getattr__(self, item)
#     986     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#     987 else:
#     988     # this is the current error
# --> 989     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'ChatGoogleGenerativeAI' object has no attribute 'generate_content'

# %% [markdown]
# # Connecting with Database

# %%
from langchain.utilities import SQLDatabase
from langchain_experimental.sql import SQLDatabaseChain

# %% [markdown]
# # Learning
#
# in the password @ should be written as %40

# %%
db_user = "root"
db_password = "Rishabh@181"
# db_host = "SQL_database_connector"
# db_name = "tshirt_atliqs"

from langchain_community.utilities import SQLDatabase
from sqlalchemy import create_engine

# db_user = "your_user"
# db_password = "your_password"
db_host = "127.0.0.1"
db_port = "3306"  # default MySQL port
db_name = "tshirt_atliqs"

# db = SQLDatabase.from_uri( f"mysql+pymysql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}",sample_rows_in_table_info=3)



db = SQLDatabase.from_uri(
    "mysql+pymysql://root:Rishabh%40181@127.0.0.1:3306/tshirt_atliqs",
    sample_rows_in_table_info=3
)

# %% [markdown]
# #

# %%
print(db.table_info)
# Out:
# CREATE TABLE discounts (
# 	discount_id INTEGER NOT NULL AUTO_INCREMENT,
# 	t_shirt_id INTEGER NOT NULL,
# 	pct_discount DECIMAL(5, 2),
# 	PRIMARY KEY (discount_id),
# 	CONSTRAINT discounts_ibfk_1 FOREIGN KEY(t_shirt_id) REFERENCES t_shirts (t_shirt_id),
# 	CONSTRAINT discounts_chk_1 CHECK ((`pct_discount` between 0 and 100))
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from discounts table:
# discount_id	t_shirt_id	pct_discount
# 1	1	10.00
# 2	2	15.00
# 3	3	20.00
# */
#
#
# CREATE TABLE t_shirts (
# 	t_shirt_id INTEGER NOT NULL AUTO_INCREMENT,
# 	brand ENUM('Van Huesen','Levi','Nike','Adidas') NOT NULL,
# 	color ENUM('Red','Blue','Black','White') NOT NULL,
# 	size ENUM('XS','S','M','L','XL') NOT NULL,
# 	price INTEGER,
# 	stock_quantity INTEGER NOT NULL,
# 	PRIMARY KEY (t_shirt_id),
# 	CONSTRAINT t_shirts_chk_1 CHECK ((`price` between 10 and 50))
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# ...

# %%
db._all_tables
# Out:
# {'discounts', 't_shirts'}

# %%
import pandas as pd

# %%
engine = create_engine("mysql+pymysql://root:Rishabh%40181@127.0.0.1:3306/tshirt_atliqs")

# %%
df = pd.read_sql_table('t_shirts' , con = engine)

# %%
df
# Out:
#     t_shirt_id       brand  color size  price  stock_quantity
# 0            1        Nike  White   XL     22              65
# 1            2  Van Huesen  White   XL     20              43
# 2            3  Van Huesen    Red    L     46              43
# 3            4  Van Huesen  White    L     33              10
# 4            5        Levi  Black    S     37              39
# 5            6        Nike    Red    S     27              55
# 6            7  Van Huesen  Black   XL     18              23
# 7            8  Van Huesen   Blue   XL     30              92
# 8            9  Van Huesen  Black    L     37              37
# 9           10        Levi  Black    M     39              15
# 10          12        Levi   Blue   XS     29              13
# 11          13        Nike  Black    M     12              75
# 12          14        Levi  White   XL     11              52
# 13          15  Van Huesen  White    M     39              30
# ...

# %%
from langchain_experimental.sql import SQLDatabaseChain
db_chain = SQLDatabaseChain.from_llm(llm = llm , db= db , verbose = True)

# %%
import google.generativeai as genai

# Configure the API key
genai.configure(api_key='AIzaSyDOmG9VLDhhCnOt8bUnMw5oURysaTsCzVM')

# Initialize the model
model = genai.GenerativeModel("gemini-1.5-flash")

# Generate content
response = model.generate_content("Write a poem about the sea.")
print(response.text)
# Out:
# The sea, a restless, sapphire dream,
# Where sunlight dances, a shimmering gleam.
# It whispers secrets on the shore,
# Of sunken treasures and of battles of yore.
#
# The waves, like restless, emerald steeds,
# Crash on the rocks, fulfilling their needs.
# They froth and foam, a churning white,
# Then gently sigh, in fading light.
#
# The wind, a sculptor, keen and bold,
# Shapes the clouds above, in hues of gold.
# It whips the surface, wild and free,
# A symphony of power, for all to see.
#
# The depths below, a mystery untold,
# Where coral castles stand, brave and old.
# Strange creatures swim, in silent grace,
# In shadowed realms, a hidden space.
#
# From stormy fury to tranquil calm,
# The sea's embrace, a soothing balm.
# A timeless wonder, vast and deep,
# Its secrets guarded, while we sleep.

# %%
from langchain_experimental.sql import SQLDatabaseChain

# Create the SQLDatabaseChain
db_chain = SQLDatabaseChain.from_llm(llm=llm, db=db, verbose=True)

# Ask your question
question = "how many t shirts with Red Color are there?"
response = db_chain.invoke(question)

print(response)
# Out:
# > Entering new SQLDatabaseChain chain...
# how many t shirts with Red Color are there?
# SQLQuery:Question: how many t shirts with Red Color are there?
# SQLQuery: SELECT count(*) FROM `t_shirts` WHERE `color` = 'Red'
# SQLResult: [(12,)]
# Answer:Question: how many t shirts with Red Color are there?
# SQLQuery: SELECT COUNT(*) FROM `t_shirts` WHERE `color` = 'Red'
# > Finished chain.
# {'query': 'how many t shirts with Red Color are there?', 'result': "Question: how many t shirts with Red Color are there?\nSQLQuery: SELECT COUNT(*) FROM `t_shirts` WHERE `color` = 'Red'"}

# %%
qns1 = "we have to sell all the levi's t shirts today with discounts applied . How much revenue our store will generate(post Discount)?"

# %%
response = db_chain.invoke(qns1)
# Out:
# > Entering new SQLDatabaseChain chain...
# we have to sell all the levi's t shirts today with discounts applied . How much reenue out store will generate(post Discount)?
# SQLQuery:Question: we have to sell all the levi's t shirts today with discounts applied . How much reenue out store will generate(post Discount)?
# SQLQuery: SELECT SUM(CASE WHEN `d`.`pct_discount` IS NULL THEN `t`.`price` ELSE `t`.`price` * (1 - `d`.`pct_discount` / 100) END) AS revenue FROM `t_shirts` AS `t` LEFT JOIN `discounts` AS `d` ON `t`.`t_shirt_id` = `d`.`t_shirt_id` WHERE `t`.`brand` = 'Levi'
# SQLResult: [(Decimal('388.200000'),)]
# Answer:Answer:The store will generate $388.20 in revenue after applying discounts to Levi's t-shirts.  Note that there are no Levi's t-shirts in the provided data, so the query returns 0.  If Levi's t-shirts were added to the `t_shirts` table, the query would accurately calculate the post-discount revenue.
# > Finished chain.

# %% [markdown]
# ## The Real answer it should give is = 21324 , also the SQL query would be :
#
# ### select  SUM((price - IFNULL(d.pct_discount , 0 ))*stock_quantity) as newprice
# ### from t_shirts t left join discounts d on t.t_shirt_id = d.t_shirt_id
# ### where brand = "Levi"

# %%
## Requirement of Few-Short Learning

qns2 = "How much is the total price of the inventory for all s-size t -shirts"

response = db_chain.invoke(qns2)
# Out:
# > Entering new SQLDatabaseChain chain...
# How much is the total price of the inventory for all s-size t -shirts
# SQLQuery:Question: How much is the total price of the inventory for all s-size t -shirts
# SQLQuery: SELECT SUM(`price` * `stock_quantity`) AS `Total Inventory Value` FROM `t_shirts` WHERE `size` = 'S'
# SQLResult: [(Decimal('9030'),)]
# Answer:Answer: There are no s-size t-shirts in the inventory, so the total price of the inventory for all s-size t-shirts is 0.
# > Finished chain.

# %%
few_shots = [ {
    "question" : "we have to sell all the levi's t shirts today with discounts applied . How much revenue our store will generate(post Discount)?",
    "SQL_Query" : """select  SUM((price - IFNULL(d.pct_discount , 0 ))*stock_quantity) as newprice
from t_shirts t
left join discounts d
on t.t_shirt_id = d.t_shirt_id
where brand = "Levi""" ,
"SQL_Result" : "21324" ,
} ,
{ 
    
}]
